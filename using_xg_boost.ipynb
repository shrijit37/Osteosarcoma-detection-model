# %% [markdown]
# <a href="https://colab.research.google.com/github/shrisrivastav/Osteosarcoma-detection-model/blob/main/using_xg_boost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###importing the drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/dataset.csv")
df.tail()
# Out:
#        X.x  Blue.count  red.count  Blue.percentage  red.percentage  \
# 1139  1140       11382      23088         1.085472        2.201843
# 1140  1141       39543     106671         3.771114       10.172939
# 1141  1142       37018      89065         3.530312        8.493900
# 1142  1143       38353      82385         3.657627        7.856846
# 1143  1144       29535     248017         2.816677       23.652744
#
#       total.clusters  average.clusters.32       area  circularity  X.1  ...  \
# 1139              82             0.075229  72.817073     0.105594  593  ...
# 1140             105             0.096330  82.514286     0.121141  594  ...
# 1141             140             0.128440  80.678571     0.128883  595  ...
# 1142             136             0.124771  75.522059     0.116099  596  ...
# 1143             132             0.121101  77.681818     0.128773  597  ...
#
#       Texture_SumEntropy_3_90  Texture_SumVariance_3_0  \
# ...

# %%
###Separting features and labels

df.shape

x, y = df.iloc[:, :-1], df.iloc[:, [-1]]
x.tail()
# Out:
#        X.x  Blue.count  red.count  Blue.percentage  red.percentage  \
# 1139  1140       11382      23088         1.085472        2.201843
# 1140  1141       39543     106671         3.771114       10.172939
# 1141  1142       37018      89065         3.530312        8.493900
# 1142  1143       38353      82385         3.657627        7.856846
# 1143  1144       29535     248017         2.816677       23.652744
#
#       total.clusters  average.clusters.32       area  circularity  X.1  ...  \
# 1139              82             0.075229  72.817073     0.105594  593  ...
# 1140             105             0.096330  82.514286     0.121141  594  ...
# 1141             140             0.128440  80.678571     0.128883  595  ...
# 1142             136             0.124771  75.522059     0.116099  596  ...
# 1143             132             0.121101  77.681818     0.128773  597  ...
#
#       Texture_SumEntropy_3_45  Texture_SumEntropy_3_90  \
# ...

# %%
y.tail()
# Out:
#      classification
# 1139      Non-Tumor
# 1140      Non-Tumor
# 1141      Non-Tumor
# 1142      Non-Tumor
# 1143      Non-Tumor

# %%
#converting csv to matrix for features
feature_matrix = x.values
print(feature_matrix)
# Out:
# [[5.48000000e+02 1.66110000e+04 5.24750000e+04 ... 1.53894292e+00
#   1.54234590e+00 1.54125575e+00]
#  [5.49000000e+02 9.31480000e+04 2.82307000e+05 ... 6.10563325e+00
#   6.10582111e+00 6.10940091e+00]
#  [5.50000000e+02 1.07853000e+05 1.98888000e+05 ... 6.17534740e+00
#   6.17609692e+00 6.17185560e+00]
#  ...
#  [1.14200000e+03 3.70180000e+04 8.90650000e+04 ... 4.41246872e+00
#   4.40376553e+00 4.41042335e+00]
#  [1.14300000e+03 3.83530000e+04 8.23850000e+04 ... 4.24697510e+00
#   4.25682996e+00 4.24869001e+00]
#  [1.14400000e+03 2.95350000e+04 2.48017000e+05 ... 1.96299841e+00
#   1.97087251e+00 1.96911310e+00]]

# %%
#converting csv to matrix for training data
result_matrix = y.values
print(result_matrix)
# Out:
# [['Non-Tumor']
#  ['Non-Tumor']
#  ['Non-Tumor']
#  ...
#  ['Non-Tumor']
#  ['Non-Tumor']
#  ['Non-Tumor']]

# %%
#traning the model

import xgboost as xgb

model = xgb.XGBClassifier(objective="binary:logistic",random_state=42)

model.fit(feature_matrix,result_matrix)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBClassifier(objective='multi:softprob', random_state=42)

# %%
pred = model.predict(feature_matrix)
for i in range(100):
  print(pred[i])
# Out:
# Non-Tumor
# Non-Tumor
# Non-Tumor
# Non-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Tumor
# Non-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Viable
# Non-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# Non-Viable-Tumor
# ...

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(result_matrix,pred)
# Out:
# array([[522,   8,   5,   1],
#        [  6, 257,   0,   0],
#        [  3,   2, 287,   0],
#        [  0,   1,   6,  46]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(result_matrix,pred)*100
# Out:
# 97.2027972027972
